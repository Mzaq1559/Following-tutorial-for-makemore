# %% [markdown]
# # Implementing Makemore by following tutorial

# %% [markdown]
# ### Reading the txt file into a list named words

# %%
words = open('names.txt', 'r').read().splitlines()

# %% [markdown]
# ### Printing first ten words

# %%
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %% [markdown]
# ### Total number of words

# %%
len(words)
# Out:
# 32033

# %% [markdown]
# ### Length of minimum word

# %%
min(len(w) for w in words)
# Out:
# 2

# %% [markdown]
# ### Length of Longest word

# %%
max(len(w) for w in words)
# Out:
# 15

# %% [markdown]
# ## Implementing Bigram language model

# %% [markdown]
# ### grouping up two letters from each word

# %%
for w in words[:3]:
    for ch1, ch2 in zip(w, w[1:]):
        print(ch1, ch2)
# Out:
# e m
# m m
# m a
# o l
# l i
# i v
# v i
# i a
# a v
# v a

# %% [markdown]
# ### checking values

# %%
w
# Out:
# 'ava'

# %%
w[1:]
# Out:
# 'va'

# %%
# declaring a dictionary for counting bigrams occurences named b
b = {}
# Adding <S> and <E> characters at the start and end of words
for w in words:
    chs = ['<S>'] + list(w) + ['<E>']
    
    for ch1, ch2 in zip(chs, chs[1:]):
        bigram = (ch1, ch2)
        b[bigram] = b.get(bigram, 0) + 1
# Out:
# <S> e
# e m
# m m
# m a
# a <E>
# <S> o
# o l
# l i
# i v
# v i
# i a
# a <E>
# <S> a
# a v
# v a
# a <E>

# %% [markdown]
# ### Printing value of b

# %%
b
# Out:
# {('<S>', 'e'): 1,
#  ('e', 'm'): 1,
#  ('m', 'm'): 1,
#  ('m', 'a'): 1,
#  ('a', '<E>'): 3,
#  ('<S>', 'o'): 1,
#  ('o', 'l'): 1,
#  ('l', 'i'): 1,
#  ('i', 'v'): 1,
#  ('v', 'i'): 1,
#  ('i', 'a'): 1,
#  ('<S>', 'a'): 1,
#  ('a', 'v'): 1,
#  ('v', 'a'): 1}
